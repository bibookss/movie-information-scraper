# %%
import requests
from bs4 import BeautifulSoup as bs
from peewee import *
from playhouse.sqlite_ext import *

# %%
host = 'localhost'
user = 'root'
password = 'password'
database = 'movies'

db = MySQLDatabase(database, host=host, user=user, password=password)

# %%
def scrape_movie_website(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
    }
    
    page = requests.get(url, headers=headers)
    soup = bs(page.content, 'html.parser')
            
    div = soup.find('div', class_='page_wrapper')
    div2 = div.find_all('div', class_='content')

    titles = []
    for div_element in div2:
        a_tags = div_element.find_all('a')
        for a_tag in a_tags:
            movie = (a_tag['title'], a_tag['href'])
            titles.append(movie)
    
    return titles

# %%
class BaseModel(Model):
    class Meta:
        database = db

class Genre(BaseModel):
    name = CharField(unique=True)
    
class Movie(BaseModel):
    name = CharField()
    url = CharField(unique=True)
    description = TextField(default=None)
    certification = CharField(default=None)
    release = DateField(default=None)
    genres = ManyToManyField(Genre)
    is_visited = BooleanField(default=False)
    
class Website(BaseModel):
    url = CharField(unique=True)
    is_visited = BooleanField(default=False)

        
db.create_tables([Genre, Movie, Movie.genres.get_through_model(), Website])

# %%
def add_genre(name):
    try:
        genre = Genre.create(name=name)
        return genre
    except IntegrityError:
        print('Genre with the same name already exists.')

def add_movie(name, url):
    try:
        url = 'https://www.themoviedb.org' + url
        movie = Movie.create(name=name, url=url) 
    except IntegrityError:
        print(f'Movie with the same url, {url}, already exists.')
        
def update_movie_details(url, description, certification, release, genres):
    try:
        release_date = datetime.datetime.strptime(release, '%m/%d/%Y').date()
        _genres = [add_genre(i) for i in genres]
        Movie.update(           
            description=description, 
            certification=certification, 
            release=release_date, 
            genres=_genres
        ).where(Movie.url == url).execute()        
    except IntegrityError:
        print('Movie not found.')

def add_website(url):
    try:
        website = Website.create(url=url)
    except IntegrityError:
        print('Website with same url already exists.')
        
def get_unvisited_websites():
    query = Website.select().where(Website.is_visited == False)
    return query

def get_unvisited_movies():
    query = Movie.select().where(Movie.is_visited == False)
    return query

def mark_website_visited(url):
    try:        
        website = Website.get(Website.url == url)
        website.is_visited = True
        website.save()
    except IntegrityError:
        print('Website does not exist')

# %%
website_url = 'https://www.themoviedb.org/movie?page='

for i in range(1, 501):
    add_website(website_url + str(i))

# %%
unvisited_websites = get_unvisited_websites()

for index, page in enumerate(unvisited_websites):
    movies = scrape_movie_website(page.url)
    
    for title, url in movies:
        add_movie(title, url)
        
    mark_website_visited(page.url)
# Out:
# Movie with the same url, https://www.themoviedb.org/movie/189349, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/10515, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/11212, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/675327, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/471506, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/183026, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/11586, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/855263, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/1015606, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/252838, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/879, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/11357, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/395990, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/662244, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/1134872, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/8867, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/1136169, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/412520, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/965143, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/770724, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/607383, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/957752, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/9994, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/428707, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/10559, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/16780, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/501190, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/532814, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/34653, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/70074, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/551591, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/192, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/962192, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/762, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/581734, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/795607, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/16538, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/7182, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/1036566, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/16, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/408270, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/246403, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/8489, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/270938, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/6023, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/377264, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/678489, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/15037, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/460885, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/463053, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/13121, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/582186, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/269, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/23916, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/413362, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/1136774, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/15947, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/785534, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/1136822, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/405775, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/1136821, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/1136844, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/19494, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/786705, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/289222, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/1136817, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/1136824, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/11159, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/24662, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/11796, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/24548, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/10549, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/1946, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/416144, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/293646, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/16804, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/359483, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/445040, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/860314, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/593680, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/417974, already exists.
# Movie with the same url, https://www.themoviedb.org/movie/17897, already exists.

# %%
for title, url in titles:
    movie = Movie(title, url)
    mar
    print(movie.get_url())
# Out:
# https://www.themoviedb.org/movie/385687
# https://www.themoviedb.org/movie/603692
# https://www.themoviedb.org/movie/502356
# https://www.themoviedb.org/movie/569094
# https://www.themoviedb.org/movie/667538
# https://www.themoviedb.org/movie/1010581
# https://www.themoviedb.org/movie/298618
# https://www.themoviedb.org/movie/536437
# https://www.themoviedb.org/movie/76600
# https://www.themoviedb.org/movie/447277
# https://www.themoviedb.org/movie/713704
# https://www.themoviedb.org/movie/1074034
# https://www.themoviedb.org/movie/447365
# https://www.themoviedb.org/movie/890771
# https://www.themoviedb.org/movie/882569
# https://www.themoviedb.org/movie/840326
# https://www.themoviedb.org/movie/640146
# https://www.themoviedb.org/movie/758323
# https://www.themoviedb.org/movie/697843
# https://www.themoviedb.org/movie/594767
